# %%
# import library
from SigProfilerAssignment import Analyzer as Analyze

# %%
# background profiles (Figure S2)
Analyze.cosmic_fit("/Users/katieskinner98/doxorubicin_mutSig/data/SigProfilerAssignment/input/background_matrix.SBS96.all",
                   "/Users/katieskinner98/doxorubicin_mutSig/data/SigProfilerAssignment/output/background_assignment/",
                   input_type="matrix", 
                   context_type="96",
                   collapse_to_SBS96=False, 
                   cosmic_version=3.5, 
                   exome=False,
                   genome_build="GRCh38", 
                   signature_database=None,
                   exclude_signature_subgroups=None, 
                   export_probabilities=False,
                   export_probabilities_per_mutation=False, 
                   make_plots=True,
                   sample_reconstruction_plots=True, 
                   verbose=False)
# Out:
# Assigning COSMIC sigs or Signature Database ......
# [Parallel(n_jobs=6)]: Using backend LokyBackend with 6 concurrent workers.
# [Parallel(n_jobs=6)]: Done   3 out of   6 | elapsed:    2.8s remaining:    2.8s
# [Parallel(n_jobs=6)]: Done   6 out of   6 | elapsed:    2.9s finished
#
# Your Job Is Successfully Completed! Thank You For Using SigProfilerAssignment.

# %%
# doxorubicin deconvolution (Figure 2)
Analyze.cosmic_fit("/Users/katieskinner98/doxorubicin_mutSig/data/SigProfilerAssignment/input/average_doxorubicin.SBS96.all",
                   "/Users/katieskinner98/doxorubicin_mutSig/data/SigProfilerAssignment/output/average_assignment/",
                   input_type="matrix", 
                   context_type="96",
                   collapse_to_SBS96=False, 
                   cosmic_version=3.5, 
                   exome=False,
                   genome_build="GRCh38", 
                   signature_database=None,
                   exclude_signature_subgroups=None, 
                   export_probabilities=False,
                   export_probabilities_per_mutation=False, 
                   make_plots=True,
                   sample_reconstruction_plots=True, 
                   verbose=False)
# Out:
# Assigning COSMIC sigs or Signature Database ......
# [Parallel(n_jobs=2)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done   2 out of   2 | elapsed:    2.4s finished
#
# Your Job Is Successfully Completed! Thank You For Using SigProfilerAssignment.
