# %%
# Doxorubicin samples topography analysis

# %%
# load libraries
from SigProfilerAssignment import Analyzer as Analyze
from SigProfilerTopography import Topography as topography
import os

# %%
# install replication timing data
topography.install_repli_seq('GRCh38', 'G401')
topography.install_repli_seq('GRCh38', 'MCF7')
topography.install_repli_seq('GRCh38', 'HEPG2')

# %%
# define input parameters
genome = "GRCh38"
input_dir = "/Users/katieskinner98/doxorubicin_mutSig/SigProfilerTopography/inputs/"
output_dir = "/Users/katieskinner98/doxorubicin_mutSig/SigProfilerTopography/outputs/"
nSims = 5

# %%
# now run each analysis...
# BT16_doxorubicin
topography.runAnalyses(genome = genome, 
                       inputDir = (input_dir + "BT16_doxorubicin/"),
                       outputDir = output_dir,
                       jobname = "BT16_doxorubicin",
                       numofSimulations = nSims,
                       transcription_strand_bias = True,
                       num_of_sbs_required=1,
                       num_of_dbs_required=1,
                       num_of_id_required=1,
                       replication_time_biosample='G401',
                       replication_time=True,
                       replication_strand_bias=True)

# %%
# CHLA-06-ATRT_doxorubicin
topography.runAnalyses(genome = genome, 
                       inputDir = (input_dir + "CHLA-06-ATRT_doxorubicin/"),
                       outputDir = output_dir,
                       jobname = "CHLA-06-ATRT_doxorubicin",
                       numofSimulations = nSims,
                       transcription_strand_bias = True,
                       num_of_sbs_required=1,
                       num_of_dbs_required=1,
                       num_of_id_required=1,
                       replication_time_biosample='G401',
                       replication_time=True,
                       replication_strand_bias=True)

# %%
# PEDS9001_T1_doxorubicin
topography.runAnalyses(genome = genome, 
                       inputDir = (input_dir + "PEDS9001_T1_doxorubicin/"),
                       outputDir = output_dir,
                       jobname = "PEDS9001_T1_doxorubicin",
                       numofSimulations = nSims,
                       transcription_strand_bias = True,
                       num_of_sbs_required=1,
                       num_of_dbs_required=1,
                       num_of_id_required=1,
                       replication_time_biosample='G401',
                       replication_time=True,
                       replication_strand_bias=True)

# %%
# PEDS0005_T1_doxorubicin
topography.runAnalyses(genome = genome, 
                       inputDir = (input_dir + "PEDS0005_T1_doxorubicin/"),
                       outputDir = output_dir,
                       jobname = "PEDS0005_T1_doxorubicin",
                       numofSimulations = nSims,
                       transcription_strand_bias = True,
                       num_of_sbs_required=1,
                       num_of_dbs_required=1,
                       num_of_id_required=1,
                       replication_time_biosample='G401',
                       replication_time=True,
                       replication_strand_bias=True)

# %%
# HepG2_doxorubicin_clone1
topography.runAnalyses(genome = genome, 
                       inputDir = (input_dir + "HepG2_doxorubicin_clone1/"),
                       outputDir = output_dir,
                       jobname = "HepG2_doxorubicin_clone1",
                       numofSimulations = nSims,
                       transcription_strand_bias = True,
                       num_of_sbs_required=1,
                       num_of_dbs_required=1,
                       num_of_id_required=1,
                       replication_time_biosample='HEPG2',
                       replication_time=True,
                       replication_strand_bias=True)

# %%
# HepG2_doxorubicin_clone2
topography.runAnalyses(genome = genome, 
                       inputDir = (input_dir + "HepG2_doxorubicin_clone2/"),
                       outputDir = output_dir,
                       jobname = "HepG2_doxorubicin_clone2",
                       numofSimulations = nSims,
                       transcription_strand_bias = True,
                       num_of_sbs_required=1,
                       num_of_dbs_required=1,
                       num_of_id_required=1,
                       replication_time_biosample='HEPG2',
                       replication_time=True,
                       replication_strand_bias=True)

# %%
# MCF10A_doxorubicin_clone1
topography.runAnalyses(genome = genome, 
                       inputDir = (input_dir + "MCF10A_doxorubicin_clone1/"),
                       outputDir = output_dir,
                       jobname = "MCF10A_doxorubicin_clone1",
                       numofSimulations = nSims,
                       transcription_strand_bias = True,
                       num_of_sbs_required=1,
                       num_of_dbs_required=1,
                       num_of_id_required=1,
                       replication_time_biosample='MCF7',
                       replication_time=True,
                       replication_strand_bias=True)

# %%
# MCF10A_doxorubicin_clone2
topography.runAnalyses(genome = genome, 
                       inputDir = (input_dir + "MCF10A_doxorubicin_clone2/"),
                       outputDir = output_dir,
                       jobname = "MCF10A_doxorubicin_clone2",
                       numofSimulations = nSims,
                       transcription_strand_bias = True,
                       num_of_sbs_required=1,
                       num_of_dbs_required=1,
                       num_of_id_required=1,
                       replication_time_biosample='MCF7',
                       replication_time=True,
                       replication_strand_bias=True)

# %%
# MCF10A_doxorubicin_clone2
topography.runAnalyses(genome = genome, 
                       inputDir = (input_dir + "MCF10A_doxorubicin_clone2/"),
                       outputDir = output_dir,
                       jobname = "MCF10A_doxorubicin_clone2",
                       numofSimulations = nSims,
                       transcription_strand_bias = True,
                       num_of_sbs_required=1,
                       num_of_dbs_required=1,
                       num_of_id_required=1,
                       replication_time_biosample='MCF7',
                       replication_time=True,
                       replication_strand_bias=True)
